# %%
import pandas as pd

# %%
df = pd.read_json('consolidated_feedback.jsonl',lines= True)

# %%
df.columns
# Out:
# Index(['campaign_id', 'user_id', 'request_id', 'auction_cpm', 'auction_cpa',
#        'auction_cpc', 'target_age_range', 'target_location', 'target_gender',
#        'target_income_bucket', 'target_device_type', 'campaign_start_time',
#        'campaign_end_time', 'expenditure_amount', 'user_action', 'timestamp',
#        'click', 'view', 'acquisition'],
#       dtype='object')

# %%
df.to_csv('consolidated_feedback.csv',index=False)

# %%
df
# Out:
#                                campaign_id  \
# 0     5487ea8a-8afa-11f0-b7f6-0e087721c0e9
# 1     7772bc8e-8aee-11f0-b7f6-0e087721c0e9
# 2     5ee63ff4-8b90-11f0-b7f6-0e087721c0e9
# 3     5ee63ff4-8b90-11f0-b7f6-0e087721c0e9
# 4     f1506942-8a90-11f0-b7f6-0e087721c0e9
# ...                                    ...
# 1179  e477950e-8a1f-11f0-b7f6-0e087721c0e9
# 1180  2deb00cc-8bdd-11f0-b7f6-0e087721c0e9
# 1181  6413362e-8b29-11f0-b7f6-0e087721c0e9
# 1182  6413362e-8b29-11f0-b7f6-0e087721c0e9
# 1183  afd8608a-8b87-11f0-b7f6-0e087721c0e9
#
#                                    user_id  \
# 0     063e41a0-174e-11eb-80dd-faffc2427b62
# 1     19f21f00-174e-11eb-80dd-faffc2427b62
# 2     045902bc-174e-11eb-80dd-faffc2427b62
# 3     0a7b5e2e-174e-11eb-80dd-faffc2427b62
# 4     0e62984a-174e-11eb-80dd-faffc2427b62
# ...                                    ...
# 1179  26024a5e-174e-11eb-80dd-faffc2427b62
# 1180  15648d56-174e-11eb-80dd-faffc2427b62
# 1181  103c58d6-174e-11eb-80dd-faffc2427b62
# ...

# %%
21/107
# Out:
# 0.19626168224299065

# %%
df[df.campaign_id =='a91ea5c8-8a1b-11f0-b7f6-0e087721c0e9']
# Out:
# Empty DataFrame
# Columns: [campaign_id, user_id, request_id, auction_cpm, auction_cpa, auction_cpc, target_age_range, target_location, target_gender, target_income_bucket, target_device_type, campaign_start_time, campaign_end_time, expenditure_amount, user_action, timestamp, click, view, acquisition]
# Index: []
